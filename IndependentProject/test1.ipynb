# %%
import regex as re
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = pd.read_csv('Electric_Vehicle_Population_Data.csv')

# %%
file.tail(50)
# Out:
#         VIN (1-10)        County              City State  Postal Code  \
# 191357  7SAXCBE51P         Clark        Ridgefield    WA      98642.0
# 191358  2C4RC1N70L   Walla Walla       Walla Walla    WA      99362.0
# 191359  7SAYGDEE3N          King           Redmond    WA      98053.0
# 191360  1G1FY6S05P         Clark        Ridgefield    WA      98642.0
# 191361  1G1RB6E48D        Pierce          Edgewood    WA      98371.0
# 191362  5YJ3E1EA7J          King           Seattle    WA      98144.0
# 191363  5YJ3E1EA1K     Snohomish       Woodinville    WA      98072.0
# 191364  1C4JJXP64M        Pierce  University Place    WA      98467.0
# 191365  7SAYGAEEXP        Pierce            Tacoma    WA      98422.0
# 191366  1C4JJXP62N       Spokane           Spokane    WA      99224.0
# 191367  7SAYGDEE4P          King         Sammamish    WA      98074.0
# 191368  WA1LAAGE6N          King  Lake Forest Park    WA      98155.0
# ...
